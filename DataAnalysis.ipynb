# %% [markdown]
# # Python- Pandas Library

# %% [markdown]
# Dataset: Motor Trend Car Road Tests 32 observations on 11 (numeric) variables. The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973--74 models).

# %% [markdown]
# # Dataset Import

# %% [markdown]
# Here we are going to import our dataset.

# %%
#import pandas library
import pandas as pd
#raed dataset and store into a dataframe
cars=pd.read_csv("mtcars2.csv")
#print
cars
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1
#
#     am  gear  carb
# 0    1     4     4
# 1    1     4     4
# 2    1     4     1
# 3    0     3     1
# 4    0     3     2
# 5    0     3     1
# 6    0     3     4
# 7    0     4     2
# 8    0     4     2
# 9    0     4     4
# 10   0     4     4
# 11   0     3     3
# 12   0     3     3
# 13   0     3     3
# 14   0     3     4
# 15   0     3     4
# 16   0     3     4
# 17   1     4     1
# 18   1     4     2
# 19   1     4     1
# 20   0     3     1
# 21   0     3     2
# 22   0     3     2
# 23   0     3     4
# 24   0     3     2
# 25   1     4     1
# 26   1     5     2
# 27   1     5     2
# 28   1     5     4
# 29   1     5     6
# 30   1     5     8
# 31   1     4     2

# %%
#to be removed before recording---to convert the mpg column to str--
cars.mpg = cars.mpg.astype(str)

# %% [markdown]
# # Analysis

# %% [markdown]
# After importing the dataset we are all set to perform different analysis.

# %%
#check the type
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
#view only the first five records
cars.head()
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
#view only the first ten records
cars.head(10)
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5     6            Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6     7         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7     8          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8     9           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9    10           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2
# 5     3     1
# 6     3     4
# 7     4     2
# 8     4     2
# 9     4     4

# %%
#view only the last five records
cars.tail()
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
#view only the last ten records
cars.tail(10)
# Out:
#     S.No        Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 22    23       AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23    24        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24    25  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25    26         Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1   1
# 26    27     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27    28      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28    29    Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29    30      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30    31     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31    32        Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
#view number of rows and columns in the dataframe
cars.shape
# Out:
# (32, 13)

# %%
#print a concise summary of the columns
cars.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
# S.No          32 non-null int64
# Unnamed: 1    32 non-null object
# mpg           32 non-null object
# cyl           32 non-null int64
# disp          32 non-null float64
# hp            32 non-null int64
# drat          32 non-null float64
# wt            32 non-null float64
# qsec          29 non-null float64
# vs            32 non-null int64
# am            32 non-null int64
# gear          32 non-null int64
# carb          32 non-null int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 3.3+ KB

# %%
#mean
cars.mean()
# Out:
# S.No     16.500000
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.674828
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
#median
cars.median()
# Out:
# S.No     16.500
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.420
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
#standard deviation
cars.std()
# Out:
# S.No      9.380832
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.780394
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
#maximum of each attribute
cars.max()
# Out:
# S.No                  32
# Unnamed: 1    Volvo 142E
# mpg                 33.9
# cyl                    8
# disp                 472
# hp                   335
# drat                4.93
# wt                 5.424
# qsec                22.9
# vs                     1
# am                     1
# gear                   5
# carb                   8
# dtype: object

# %%
#minimum of each attribute
cars.min()
# Out:
# S.No                    1
# Unnamed: 1    AMC Javelin
# mpg                  10.4
# cyl                     4
# disp                 71.1
# hp                     52
# drat                 2.76
# wt                  1.513
# qsec                 14.5
# vs                      0
# am                      0
# gear                    3
# carb                    1
# dtype: object

# %%
#number of non-null records in each column
cars.count()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
#descriptive statistics summary
cars.describe()
# Out:
#             S.No        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   16.500000   6.187500  230.721875  146.687500   3.596563   3.217250
# std     9.380832   1.785922  123.938694   68.562868   0.534679   0.978457
# min     1.000000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%     8.750000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    16.500000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    24.250000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    32.000000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  29.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.674828   0.437500   0.406250   3.687500   2.8125
# std     1.780394   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.870000   0.000000   0.000000   3.000000   2.0000
# 50%    17.420000   0.000000   0.000000   4.000000   2.0000
# 75%    18.600000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
cars
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1
#
#     am  gear  carb
# 0    1     4     4
# 1    1     4     4
# 2    1     4     1
# 3    0     3     1
# 4    0     3     2
# 5    0     3     1
# 6    0     3     4
# 7    0     4     2
# 8    0     4     2
# 9    0     4     4
# 10   0     4     4
# 11   0     3     3
# 12   0     3     3
# 13   0     3     3
# 14   0     3     4
# 15   0     3     4
# 16   0     3     4
# 17   1     4     1
# 18   1     4     2
# 19   1     4     1
# 20   0     3     1
# 21   0     3     2
# 22   0     3     2
# 23   0     3     4
# 24   0     3     2
# 25   1     4     1
# 26   1     5     2
# 27   1     5     2
# 28   1     5     4
# 29   1     5     6
# 30   1     5     8
# 31   1     4     2

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# After analysing we have realized that our dataset is not perfect, some column names are irrelevant, there are a few missing data, some column has important data but can't perform some operation because they are of string type. So now with the help of pandas we will be cleaning or in other words we will be making our data perfect to perform further operations.

# %%
#rename column
cars=cars.rename(columns={'Unnamed: 1':'model'})
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1
#
#     am  gear  carb
# 0    1     4     4
# 1    1     4     4
# 2    1     4     1
# 3    0     3     1
# 4    0     3     2
# 5    0     3     1
# 6    0     3     4
# 7    0     4     2
# 8    0     4     2
# 9    0     4     4
# 10   0     4     4
# 11   0     3     3
# 12   0     3     3
# 13   0     3     3
# 14   0     3     4
# 15   0     3     4
# 16   0     3     4
# 17   1     4     1
# 18   1     4     2
# 19   1     4     1
# 20   0     3     1
# 21   0     3     2
# 22   0     3     2
# 23   0     3     4
# 24   0     3     2
# 25   1     4     1
# 26   1     5     2
# 27   1     5     2
# 28   1     5     4
# 29   1     5     6
# 30   1     5     8
# 31   1     4     2

# %%
#Fill the null values with mean of the column
cars.qsec=cars.qsec.fillna(cars.qsec.mean())
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
#
#     vs  am  gear  carb
# 0    0   1     4     4
# 1    0   1     4     4
# 2    1   1     4     1
# 3    1   0     3     1
# 4    0   0     3     2
# 5    1   0     3     1
# 6    0   0     3     4
# 7    1   0     4     2
# 8    1   0     4     2
# 9    1   0     4     4
# 10   1   0     4     4
# 11   0   0     3     3
# 12   0   0     3     3
# 13   0   0     3     3
# 14   0   0     3     4
# 15   0   0     3     4
# 16   0   0     3     4
# 17   1   1     4     1
# 18   1   1     4     2
# 19   1   1     4     1
# 20   1   0     3     1
# 21   0   0     3     2
# 22   0   0     3     2
# 23   0   0     3     4
# 24   0   0     3     2
# 25   1   1     4     1
# 26   0   1     5     2
# 27   1   1     5     2
# 28   0   1     5     4
# 29   0   1     5     6
# 30   0   1     5     8
# 31   1   1     4     2

# %%
#drop unwanted column
#cars = cars.drop(columns=['S.No'])
#cars

# %%
# checking the types of all coumns of dataframe
cars.dtypes
# Out:
# S.No       int64
# model     object
# mpg       object
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
#find correlation matrix
df=cars[['mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']].corr()
df
#you can see mpg is of string type so we can't perform correlation.
# Out:
#            cyl      disp        hp      drat        wt      qsec        vs  \
# cyl   1.000000  0.902033  0.832447 -0.699938  0.782496 -0.548775 -0.810812
# disp  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.385207 -0.710416
# hp    0.832447  0.790949  1.000000 -0.448759  0.658748 -0.650674 -0.723097
# drat -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.120175  0.440278
# wt    0.782496  0.887980  0.658748 -0.712441  1.000000 -0.130362 -0.554916
# qsec -0.548775 -0.385207 -0.650674  0.120175 -0.130362  1.000000  0.667873
# vs   -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.667873  1.000000
# am   -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.271763  0.168345
# gear -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.203784  0.206023
# carb  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.573987 -0.569607
#
#             am      gear      carb
# cyl  -0.522607 -0.492687  0.526988
# disp -0.591227 -0.555569  0.394977
# hp   -0.243204 -0.125704  0.749812
# drat  0.712711  0.699610 -0.090790
# wt   -0.692495 -0.583287  0.427606
# qsec -0.271763 -0.203784 -0.573987
# vs    0.168345  0.206023 -0.569607
# am    1.000000  0.794059  0.057534
# gear  0.794059  1.000000  0.274073
# carb  0.057534  0.274073  1.000000

# %%
#So change mpg from string to float to perform correlation
cars.mpg = cars.mpg.astype(float)
#see the change
cars.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
# S.No     32 non-null int64
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.3+ KB

# %%
#Again find the correlation including mpg
df=cars[['mpg', 'cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']].corr()
df
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.360351
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.548775
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.385207
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.650674
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.120175
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.130362
# qsec  0.360351 -0.548775 -0.385207 -0.650674  0.120175 -0.130362  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.667873
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.271763
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.203784
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.573987
#
#             vs        am      gear      carb
# mpg   0.664039  0.599832  0.480285 -0.550925
# cyl  -0.810812 -0.522607 -0.492687  0.526988
# disp -0.710416 -0.591227 -0.555569  0.394977
# hp   -0.723097 -0.243204 -0.125704  0.749812
# drat  0.440278  0.712711  0.699610 -0.090790
# wt   -0.554916 -0.692495 -0.583287  0.427606
# qsec  0.667873 -0.271763 -0.203784 -0.573987
# vs    1.000000  0.168345  0.206023 -0.569607
# am    0.168345  1.000000  0.794059  0.057534
# gear  0.206023  0.794059  1.000000  0.274073
# carb -0.569607  0.057534  0.274073  1.000000

# %% [markdown]
# Now from the correlation we can see lowest correlation is between "am" and "carb". So when we will taking "carb" as reference for any analysis we can drop "am", since it will not add any change or value to the analysis. In the same way we can drop "carb" column while taking "am" as reference for any analysis.

# %%
Q1 = df.quantile(0.25)
Q1
# Out:
# mpg    -0.811860
# cyl    -0.624357
# disp   -0.650720
# hp     -0.549716
# drat   -0.574349
# wt     -0.637891
# qsec   -0.466991
# vs     -0.640012
# am     -0.397185
# gear   -0.348235
# carb   -0.320857
# Name: 0.25, dtype: float64

# %%
Q3 = df.quantile(0.75)
Q3
# Out:
# mpg     0.631936
# cyl     0.807472
# disp    0.839464
# hp      0.770381
# drat    0.690391
# wt      0.720622
# qsec    0.240263
# vs      0.552159
# am      0.656272
# gear    0.589947
# carb    0.477297
# Name: 0.75, dtype: float64

# %%
df=df.quantile([0.25,0.5,0.75])
df
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# 0.25 -0.811860 -0.624357 -0.650720 -0.549716 -0.574349 -0.637891 -0.466991
# 0.50  0.360351 -0.492687 -0.385207 -0.125704  0.120175 -0.130362 -0.203784
# 0.75  0.631936  0.807472  0.839464  0.770381  0.690391  0.720622  0.240263
#
#             vs        am      gear      carb
# 0.25 -0.640012 -0.397185 -0.348235 -0.320857
# 0.50  0.168345  0.057534  0.206023  0.274073
# 0.75  0.552159  0.656272  0.589947  0.477297

# %% [markdown]
# # Manipluation

# %% [markdown]
# Sometimes we don't need the whole dataset for analysis and cut them in small chunks, sometimes we need to arrange them in an certain order(ascending or descending), sometimes we may need to set a certain value to a column or apply a function to a column, sometmes we may also need to apply filters to our dataset---all of these comes under Pandas Data Manipulation.

# %% [markdown]
# # Indexing by position

# %%
#view hp column only
cars.iloc[:,4]
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: disp, dtype: float64

# %%
#first five records of hp column
cars.iloc[0:5,4]
# Out:
# 0    160.0
# 1    160.0
# 2    108.0
# 3    258.0
# 4    360.0
# Name: disp, dtype: float64

# %%
#all rows, all columns
cars.iloc[:,:]
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
#
#     vs  am  gear  carb
# 0    0   1     4     4
# 1    0   1     4     4
# 2    1   1     4     1
# 3    1   0     3     1
# 4    0   0     3     2
# 5    1   0     3     1
# 6    0   0     3     4
# 7    1   0     4     2
# 8    1   0     4     2
# 9    1   0     4     4
# 10   1   0     4     4
# 11   0   0     3     3
# 12   0   0     3     3
# 13   0   0     3     3
# 14   0   0     3     4
# 15   0   0     3     4
# 16   0   0     3     4
# 17   1   1     4     1
# 18   1   1     4     2
# 19   1   1     4     1
# 20   1   0     3     1
# 21   0   0     3     2
# 22   0   0     3     2
# 23   0   0     3     4
# 24   0   0     3     2
# 25   1   1     4     1
# 26   0   1     5     2
# 27   1   1     5     2
# 28   0   1     5     4
# 29   0   1     5     6
# 30   0   1     5     8
# 31   1   1     4     2

# %%
#for attributes from hp to carb see all the records from index 6
cars.iloc[6:,4:]
# Out:
#      disp   hp  drat     wt       qsec  vs  am  gear  carb
# 6   360.0  245  3.21  3.570  15.840000   0   0     3     4
# 7   146.7   62  3.69  3.190  20.000000   1   0     4     2
# 8   140.8   95  3.92  3.150  22.900000   1   0     4     2
# 9   167.6  123  3.92  3.440  18.300000   1   0     4     4
# 10  167.6  123  3.92  3.440  18.900000   1   0     4     4
# 11  275.8  180  3.07  4.070  17.400000   0   0     3     3
# 12  275.8  180  3.07  3.730  17.600000   0   0     3     3
# 13  275.8  180  3.07  3.780  18.000000   0   0     3     3
# 14  472.0  205  2.93  5.250  17.980000   0   0     3     4
# 15  460.0  215  3.00  5.424  17.820000   0   0     3     4
# 16  440.0  230  3.23  5.345  17.420000   0   0     3     4
# 17   78.7   66  4.08  2.200  17.674828   1   1     4     1
# 18   75.7   52  4.93  1.615  18.520000   1   1     4     2
# 19   71.1   65  4.22  1.835  19.900000   1   1     4     1
# 20  120.1   97  3.70  2.465  20.010000   1   0     3     1
# 21  318.0  150  2.76  3.520  16.870000   0   0     3     2
# 22  304.0  150  3.15  3.435  17.300000   0   0     3     2
# 23  350.0  245  3.73  3.840  15.410000   0   0     3     4
# 24  400.0  175  3.08  3.845  17.050000   0   0     3     2
# 25   79.0   66  4.08  1.935  17.674828   1   1     4     1
# 26  120.3   91  4.43  2.140  16.700000   0   1     5     2
# 27   95.1  113  3.77  1.513  16.900000   1   1     5     2
# 28  351.0  264  4.22  3.170  14.500000   0   1     5     4
# 29  145.0  175  3.62  2.770  15.500000   0   1     5     6
# 30  301.0  335  3.54  3.570  14.600000   0   1     5     8
# 31  121.0  109  4.11  2.780  18.600000   1   1     4     2

# %%
#Now we want to look at all the rows and only the first column
cars.iloc[:,1]
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %% [markdown]
# # indexing by label

# %%
#see all the record of mpg column
cars.loc[:,"mpg"]
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
#display the records from index 0 to index 6 from mpg column
cars.loc[:6,"mpg"]
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# 5    18.1
# 6    14.3
# Name: mpg, dtype: float64

# %%
#see the first 7 records from mpg to qsec column
cars.loc[:6,"mpg":"qsec"]
# Out:
#     mpg  cyl   disp   hp  drat     wt       qsec
# 0  21.0    6  160.0  110  3.90  2.620  16.460000
# 1  21.0    6  160.0  110  3.90  2.875  17.020000
# 2  22.8    4  108.0   93  3.85  2.320  18.610000
# 3  21.4    6  258.0  110  3.08  3.215  19.440000
# 4  18.7    8  360.0  175  3.15  3.440  17.020000
# 5  18.1    6  225.0  105  2.76  3.460  17.674828
# 6  14.3    8  360.0  245  3.21  3.570  15.840000

# %%
#set value 1 to column 'am'
cars['am'] = 1
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
#
#     vs  am  gear  carb
# 0    0   1     4     4
# 1    0   1     4     4
# 2    1   1     4     1
# 3    1   1     3     1
# 4    0   1     3     2
# 5    1   1     3     1
# 6    0   1     3     4
# 7    1   1     4     2
# 8    1   1     4     2
# 9    1   1     4     4
# 10   1   1     4     4
# 11   0   1     3     3
# 12   0   1     3     3
# 13   0   1     3     3
# 14   0   1     3     4
# 15   0   1     3     4
# 16   0   1     3     4
# 17   1   1     4     1
# 18   1   1     4     2
# 19   1   1     4     1
# 20   1   1     3     1
# 21   0   1     3     2
# 22   0   1     3     2
# 23   0   1     3     4
# 24   0   1     3     2
# 25   1   1     4     1
# 26   0   1     5     2
# 27   1   1     5     2
# 28   0   1     5     4
# 29   0   1     5     6
# 30   0   1     5     8
# 31   1   1     4     2

# %%
#double up records in 'am' using lambda fxn
f = lambda x: x*2
cars['am']= cars['am'].apply(f)
cars
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
#
#     vs  am  gear  carb
# 0    0   2     4     4
# 1    0   2     4     4
# 2    1   2     4     1
# 3    1   2     3     1
# 4    0   2     3     2
# 5    1   2     3     1
# 6    0   2     3     4
# 7    1   2     4     2
# 8    1   2     4     2
# 9    1   2     4     4
# 10   1   2     4     4
# 11   0   2     3     3
# 12   0   2     3     3
# 13   0   2     3     3
# 14   0   2     3     4
# 15   0   2     3     4
# 16   0   2     3     4
# 17   1   2     4     1
# 18   1   2     4     2
# 19   1   2     4     1
# 20   1   2     3     1
# 21   0   2     3     2
# 22   0   2     3     2
# 23   0   2     3     4
# 24   0   2     3     2
# 25   1   2     4     1
# 26   0   2     5     2
# 27   1   2     5     2
# 28   0   2     5     4
# 29   0   2     5     6
# 30   0   2     5     8
# 31   1   2     4     2

# %% [markdown]
# # Sorting

# %%
#sorting cyl column ascending order
cars.sort_values(by='cyl')
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
#
#     vs  am  gear  carb
# 31   1   2     4     2
# 2    1   2     4     1
# 27   1   2     5     2
# 26   0   2     5     2
# 25   1   2     4     1
# 20   1   2     3     1
# 7    1   2     4     2
# 8    1   2     4     2
# 19   1   2     4     1
# 18   1   2     4     2
# 17   1   2     4     1
# 29   0   2     5     6
# 0    0   2     4     4
# 1    0   2     4     4
# 3    1   2     3     1
# 10   1   2     4     4
# 9    1   2     4     4
# 5    1   2     3     1
# 13   0   2     3     3
# 28   0   2     5     4
# 4    0   2     3     2
# 24   0   2     3     2
# 23   0   2     3     4
# 22   0   2     3     2
# 21   0   2     3     2
# 6    0   2     3     4
# 11   0   2     3     3
# 16   0   2     3     4
# 30   0   2     5     8
# 14   0   2     3     4
# 12   0   2     3     3
# 15   0   2     3     4

# %%
#sort cyl in descending order
cars.sort_values(by='cyl', ascending=False)
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt       qsec  \
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.000000
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.980000
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.820000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.500000
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.674828
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.520000
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.900000
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.010000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.674828
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.700000
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.900000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.600000
#
#     vs  am  gear  carb
# 16   0   2     3     4
# 30   0   2     5     8
# 4    0   2     3     2
# 28   0   2     5     4
# 6    0   2     3     4
# 24   0   2     3     2
# 23   0   2     3     4
# 22   0   2     3     2
# 21   0   2     3     2
# 11   0   2     3     3
# 12   0   2     3     3
# 13   0   2     3     3
# 14   0   2     3     4
# 15   0   2     3     4
# 1    0   2     4     4
# 29   0   2     5     6
# 0    0   2     4     4
# 10   1   2     4     4
# 9    1   2     4     4
# 5    1   2     3     1
# 3    1   2     3     1
# 17   1   2     4     1
# 18   1   2     4     2
# 19   1   2     4     1
# 20   1   2     3     1
# 8    1   2     4     2
# 7    1   2     4     2
# 25   1   2     4     1
# 26   0   2     5     2
# 27   1   2     5     2
# 2    1   2     4     1
# 31   1   2     4     2

# %% [markdown]
# # Filtering

# %%
#filter records with more than 6 cylinders
cars['cyl'] > 6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
#filter records with more than 6 cylinders
filter1 = cars['cyl'] > 6
#apply filter to dataframe
filtered_new = cars[filter1]
#view filtered dataframe
filtered_new
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0
#
#     am  gear  carb
# 4    2     3     2
# 6    2     3     4
# 11   2     3     3
# 12   2     3     3
# 13   2     3     3
# 14   2     3     4
# 15   2     3     4
# 16   2     3     4
# 21   2     3     2
# 22   2     3     2
# 23   2     3     4
# 24   2     3     2
# 28   2     5     4
# 30   2     5     8

# %%
#filter records with more than 6 cyl and hp more than 300
filter2 = (cars["cyl"] > 6) & (cars["hp"] > 300)
#apply filter to dataframe
filtered_review = cars[filter2]
#display filtered data
filtered_review
# Out:
#     S.No          model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 30    31  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   2
#
#     gear  carb
# 30     5     8

# %% [markdown]
# # Data Visualization

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
#see how hp varies with each car with line plot
y1 = cars['hp']
x  = range(32)
plt.plot(x,y1)

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
#see how hp varies with each car with line plot
y2 = cars['disp']
x  = range(32)
plt.plot(x,y2)

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
#see how both hp and disp varies 
x  = range(32)
plt.plot(x,y1, label='hp')
plt.plot(x,y2, label='disp')
plt.legend()
#plt.legend([y1, y2], ['hp','disp'])
#plt.legend(handles=[y1, y2])
plt.show()

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x  = range(32)
#area plot of hp and disp 
plt.stackplot(x,y1,colors = 'purple', alpha = 0.7)
plt.stackplot(x,y2,colors = 'black', alpha = 0.5)

# %%
import matplotlib.pyplot  as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x  = range(32)
#plot both line plot and area plot to see the margin
plt.plot(x,y1, linewidth = 2.0, color = 'c')
plt.stackplot(x,y1,colors = 'purple', alpha = 0.7)
plt.plot(x,y2, linewidth = 1.0, color = 'r')
plt.stackplot(x,y2,colors = 'black', alpha = 0.5)

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y = cars['hp']
x  = range(32)
#model to list
x1 = cars['model'].tolist()
#adding figure to adjust figsize
fig = plt.figure(figsize = (30,15))
#see how hp changes with bar plot
plt.bar(x1,y,color="purple", alpha=0.9)
# Out:
# <BarContainer object of 32 artists>

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y = cars['hp']
x  = range(32)
x1 = cars['model'].tolist()
fig = plt.figure(figsize = (17,10))
#to avoid the overlapping issue plot horizontal bar plot
plt.barh(x1,y, color="purple", alpha=0.8)
# Out:
# <BarContainer object of 32 artists>

# %%
boxplot =cars.boxplot(column=['hp', 'disp', 'qsec'])
